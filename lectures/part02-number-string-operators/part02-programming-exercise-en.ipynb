# %% [markdown]
# # Chapter 2 Programming Exercises — Exact statements from the PDF
#
# **Source:** *Python for Everyone, 3rd Edition* — Cay Horstmann & Rance Necaise
# **Chapter 2:** *Programming with Numbers and Strings*
#
# The exercise statements below are reproduced **directly from the provided PDF without translating, paraphrasing, shortening, or rewriting them**.
#
# Each exercise is followed by a blank Python code cell for your work. No solutions are included.

# %% [markdown]
# # Programming Exercises

# %% [markdown]
# ## P2.1
#
# ![P2.1 source excerpt](attachment:p2_1_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.2
#
# ![P2.2 source excerpt](attachment:p2_2_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.3
#
# ![P2.3 source excerpt](attachment:p2_3_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.4
#
# ![P2.4 source excerpt](attachment:p2_4_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.5
#
# ![P2.5 source excerpt](attachment:p2_5_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.6
#
# ![P2.6 source excerpt](attachment:p2_6_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.7
#
# ![P2.7 source excerpt](attachment:p2_7_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.8
#
# ![P2.8 source excerpt](attachment:p2_8_1.png)
#
# ![P2.8 source excerpt](attachment:p2_8_2.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.9
#
# ![P2.9 source excerpt](attachment:p2_9_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.10
#
# ![P2.10 source excerpt](attachment:p2_10_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.11
#
# ![P2.11 source excerpt](attachment:p2_11_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.12
#
# ![P2.12 source excerpt](attachment:p2_12_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.13
#
# ![P2.13 source excerpt](attachment:p2_13_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.14
#
# ![P2.14 source excerpt](attachment:p2_14_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.15
#
# ![P2.15 source excerpt](attachment:p2_15_1.png)
#
# ![P2.15 source excerpt](attachment:p2_15_2.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.16
#
# ![P2.16 source excerpt](attachment:p2_16_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.17
#
# ![P2.17 source excerpt](attachment:p2_17_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.18
#
# ![P2.18 source excerpt](attachment:p2_18_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.19
#
# ![P2.19 source excerpt](attachment:p2_19_1.png)
#
# ![P2.19 source excerpt](attachment:p2_19_2.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.20
#
# ![P2.20 source excerpt](attachment:p2_20_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.21
#
# ![P2.21 source excerpt](attachment:p2_21_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.22
#
# ![P2.22 source excerpt](attachment:p2_22_1.png)

# %%
# Write your solution here

# %% [markdown]
# # Business

# %% [markdown]
# ## P2.32
#
# ![P2.32 source excerpt](attachment:p2_32_1.png)
#
# ![P2.32 source excerpt](attachment:p2_32_2.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.33
#
# ![P2.33 source excerpt](attachment:p2_33_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.34
#
# ![P2.34 source excerpt](attachment:p2_34_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.35
#
# ![P2.35 source excerpt](attachment:p2_35_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.36
#
# ![P2.36 source excerpt](attachment:p2_36_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.37
#
# ![P2.37 source excerpt](attachment:p2_37_1.png)
#
# ![P2.37 source excerpt](attachment:p2_37_2.png)

# %%
# Write your solution here

# %% [markdown]
# # Science

# %% [markdown]
# ## P2.38
#
# ![P2.38 source excerpt](attachment:p2_38_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.39
#
# ![P2.39 source excerpt](attachment:p2_39_1.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.40
#
# ![P2.40 source excerpt](attachment:p2_40_1.png)
#
# ![P2.40 source excerpt](attachment:p2_40_2.png)

# %%
# Write your solution here

# %% [markdown]
# ## P2.43
#
# ![P2.43 source excerpt](attachment:p2_43_1.png)

# %%
# Write your solution here
